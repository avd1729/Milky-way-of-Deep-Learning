# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
data = pd.read_csv('C:/Users/Aravind/Work/PROJECTS/Milky-way-of-Deep-Learning/Milky-way-of-Deep-Learning/data/external/Milk_MIR_Traits_data_2023.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Columns: 582 entries, Breed to 3822
# dtypes: float64(580), object(2)
# memory usage: 1.9+ MB

# %%
data.describe()
# Out:
#            Parity  Milking_Time  DaysInMilk  Protein_content  kappa_casein
# count  430.000000    430.000000  430.000000       431.000000    307.000000  \
# mean     2.530233      1.316279  125.120930         3.583271      5.733479
# std      1.692646      0.465565   71.455427         0.529114      1.914361
# min      1.000000      1.000000    5.000000         1.130000      1.357356
# 25%      1.000000      1.000000   66.000000         3.300000      4.716430
# 50%      2.000000      1.000000  124.000000         3.540000      5.492220
# 75%      3.000000      2.000000  182.000000         3.855000      6.676350
# max     11.000000      2.000000  375.000000         5.980000     22.233240
#
#        alpha_s2_casein  alpha_s1_casein  beta_casein  alpha_lactalbumin
# count       307.000000       307.000000   307.000000         307.000000  \
# mean          3.450119        13.819168    12.605092           1.199054
# std           1.063301         3.629001     3.136411           0.723567
# ...

# %%
data.head()
# Out:
#      Breed Date_of_sampling  Parity  Milking_Time  DaysInMilk
# 0  Hol Fri       20/08/2013     5.0           1.0       197.0  \
# 1  Hol Fri       20/08/2013     5.0           1.0       203.0
# 2     JEX-       20/08/2013     5.0           1.0       193.0
# 3     FRX-       20/08/2013     4.0           1.0       119.0
# 4     JEX-       20/08/2013     5.0           1.0       206.0
#
#    Protein_content  kappa_casein  alpha_s2_casein  alpha_s1_casein
# 0             3.35       5.30620         3.129512         12.09580  \
# 1             3.48       6.10762         3.722658         12.63136
# 2             3.61       7.05540         0.657284         12.47792
# 3             3.64       8.28818         6.145520         21.83550
# 4             4.20       7.30404         4.022390         16.78622
#
#    beta_casein  ...      3788      3791      3795      3799      3803
# 0      9.70916  ...  0.028741  0.029182  0.029620  0.030060  0.030488  \
# ...
